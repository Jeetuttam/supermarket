# %% [markdown]
# # Jitender Kumar 1st Task

# %% [markdown]
# # EDA on Superstore Dataset

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# __Performing EDA on dataset 'Samplesuperstore'__
#
# __Analyse the data and show the area where you should work more to make profit__

# %%
super_store=pd.read_csv('SampleSuperstore.csv')#assining the data

# %%
super_store.head()# Here is the head of data
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
super_store.shape#total shape(total rows=9994,total column=13)
# Out:
# (9994, 13)

# %%
super_store.info()#information of the data which one is categorical,numerical and so on
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
super_store.describe()# detail info of data (min, max,mid,std deviation and total count)etc.
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ## Wraggling the data

# %%
super_store.isna().sum().to_frame()#it is a clean data
# Out:
#               0
# Ship Mode     0
# Segment       0
# Country       0
# City          0
# State         0
# Postal Code   0
# Region        0
# Category      0
# Sub-Category  0
# Sales         0
# Quantity      0
# Discount      0
# Profit        0

# %% [markdown]
# ### check whether the dta has any null value or not
# - Here we can see that there is no any null value
# - so we don't need to clean it

# %%
super_store.columns#total columns present in the dataset
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
super_store.dtypes.to_frame()#types of data i.e. object,float,int
# Out:
#                     0
# Ship Mode      object
# Segment        object
# Country        object
# City           object
# State          object
# Postal Code     int64
# Region         object
# Category       object
# Sub-Category   object
# Sales         float64
# Quantity        int64
# Discount      float64
# Profit        float64

# %% [markdown]
# ## check whether data has any duplicate value if have then drop it

# %%
super_store.duplicated().sum()
# Out:
# 17

# %%
super_store.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
pd.DataFrame(super_store['Ship Mode'].value_counts())# total count of ship mode
# Out:
#                 Ship Mode
# Standard Class       5968
# Second Class         1945
# First Class          1538
# Same Day              543

# %%
super_store['Ship Mode'].value_counts().plot.barh();

# %%
#Sales per Ship mode
super_store.groupby('Ship Mode')['Sales','Profit'].agg(['sum']).plot.bar()
plt.title('Year wise Total Sales & % of profit gained\n');

# %% [markdown]
# - Here we can see that standard class is having highest sales

# %%
pd.DataFrame(super_store['Segment'].value_counts())
# Out:
#              Segment
# Consumer        5191
# Corporate       3020
# Home Office     1783

# %% [markdown]
#  _just cheking the segment_
#  - consumer segment is doing better with respect to other segment

# %%
sns.countplot(x=super_store['Segment']);

# %%
pd.DataFrame(super_store['Category'].value_counts())
# Out:
#                  Category
# Office Supplies      6026
# Furniture            2121
# Technology           1847

# %%
pd.DataFrame(super_store['Category'].value_counts()).plot.bar()
# Out:
# <AxesSubplot:>

# %%
super_store.groupby('Category')['Profit','Sales'].agg(['sum']).plot.bar();

# %%
plt.figure(figsize=[16,8])
plt.bar('Sub-Category','Category', data=super_store);

# %%
super_store.drop('Postal Code',axis=1,inplace=True)# dropping postalcode which is of no use

# %%
pd.DataFrame(super_store['State'].value_counts())
# Out:
#                       State
# California             2001
# New York               1128
# Texas                   985
# Pennsylvania            587
# Washington              506
# Illinois                492
# Ohio                    469
# Florida                 383
# Michigan                255
# North Carolina          249
# Arizona                 224
# Virginia                224
# Georgia                 184
# Tennessee               183
# Colorado                182
# Indiana                 149
# Kentucky                139
# Massachusetts           135
# New Jersey              130
# Oregon                  124
# Wisconsin               110
# Maryland                105
# Delaware                 96
# Minnesota                89
# Connecticut              82
# Missouri                 66
# Oklahoma                 66
# Alabama                  61
# Arkansas                 60
# Rhode Island             56
# Mississippi              53
# Utah                     53
# ...

# %%
top_state=super_store.groupby('State').sum().sort_values('Profit',ascending=False)
top_state.head(15)
# Out:
#                      Sales  Quantity  Discount      Profit
# State
# California     457687.6315      7667     145.6  76381.3871
# New York       310876.2710      4224      62.4  74038.5486
# Washington     138641.2700      1883      32.4  33402.6517
# Michigan        76269.6140       946       1.8  24463.1876
# Virginia        70636.7200       893       0.0  18597.9504
# Indiana         53555.3600       578       0.0  18382.9363
# Georgia         49095.8400       705       0.0  16250.0433
# Kentucky        36591.7500       523       0.0  11199.6966
# Minnesota       29863.1500       331       0.0  10823.1874
# Delaware        27451.0690       367       0.6   9977.3748
# New Jersey      35764.3120       454       0.6   9772.9138
# Wisconsin       32114.6100       463       0.0   8401.8004
# Rhode Island    22627.9560       199       1.2   7285.6293
# Maryland        23705.5230       420       0.6   7031.1788
# Massachusetts   28634.4340       491       2.1   6785.5016

# %% [markdown]
# - California, New York and Texas doing better business while Wyoming is the worst one
# - we should must take care why they are doing worst business

# %%
# let's undestand it by plot
plt.figure(figsize=[16,10])
sns.countplot(x=super_store['State'])
plt.xticks(rotation=90);

# %%
super_store['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
super_store.groupby('Sub-Category').mean()
# Out:
#                     Sales  Quantity  Discount      Profit
# Sub-Category
# Accessories    215.974604  3.840000  0.078452   54.111788
# Appliances     230.755710  3.710300  0.166524   38.922758
# Art             34.068834  3.768844  0.074874    8.200737
# Binders        133.560560  3.922521  0.372292   19.843574
# Bookcases      503.859633  3.807018  0.211140  -15.230509
# Chairs         532.332420  3.818476  0.170178   43.095894
# Copiers       2198.941618  3.441176  0.161765  817.909190
# Envelopes       64.867724  3.566929  0.080315   27.418019
# Fasteners       13.936774  4.211982  0.082028    4.375660
# Furnishings     95.825668  3.723093  0.138349   13.645918
# Labels          34.303055  3.846154  0.068681   15.236962
# Machines      1645.553313  3.826087  0.306087   29.432669
# Paper           57.284092  3.779562  0.074891   24.856620
# Phones         371.211534  3.699663  0.154556   50.073938
# Storage        264.590553  3.732861  0.074704   25.152277
# ...

# %%
super_store.groupby('Sub-Category').min()
# Out:
#                 Ship Mode   Segment        Country       City    State  \
# Sub-Category
# Accessories   First Class  Consumer  United States      Akron  Alabama
# Appliances    First Class  Consumer  United States    Abilene  Alabama
# Art           First Class  Consumer  United States      Akron  Alabama
# Binders       First Class  Consumer  United States      Akron  Alabama
# Bookcases     First Class  Consumer  United States   Amarillo  Arizona
# Chairs        First Class  Consumer  United States   Amarillo  Alabama
# Copiers       First Class  Consumer  United States  Arlington  Alabama
# Envelopes     First Class  Consumer  United States  Ann Arbor  Alabama
# Fasteners     First Class  Consumer  United States      Akron  Alabama
# Furnishings   First Class  Consumer  United States      Akron  Alabama
# Labels        First Class  Consumer  United States   Appleton  Alabama
# Machines      First Class  Consumer  United States  Arlington  Alabama
# ...

# %% [markdown]
# -  central region doing negative sell
# - except copier,paper,envelopes,arts and labels

# %%
super_store.groupby('Sub-Category').max()
# Out:
#                    Ship Mode      Segment        Country         City  \
# Sub-Category
# Accessories   Standard Class  Home Office  United States         Yuma
# Appliances    Standard Class  Home Office  United States   Wilmington
# Art           Standard Class  Home Office  United States         Yuma
# Binders       Standard Class  Home Office  United States         Yuma
# Bookcases     Standard Class  Home Office  United States   Wilmington
# Chairs        Standard Class  Home Office  United States         York
# Copiers       Standard Class  Home Office  United States      Warwick
# Envelopes     Standard Class  Home Office  United States   Wilmington
# Fasteners     Standard Class  Home Office  United States  Westminster
# Furnishings   Standard Class  Home Office  United States      Yonkers
# Labels        Standard Class  Home Office  United States     Woodland
# Machines      Standard Class  Home Office  United States         Yuma
# ...

# %% [markdown]
# - In western region each sub-category doing well especially Copier,Binders and Machines

# %%
# we can see it by ploting  sub-category
plt.figure(figsize=[12,8])
sns.countplot(x=super_store['Sub-Category'])
plt.xticks(rotation=90);

# %%
super_store.groupby('Sub-Category')['Profit','Sales'].agg(['sum']).plot.bar();# here copier and accesories doing more profit w.r.t sales

# %%
corr=super_store.corr()
corr
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='GnBu_r',linecolor='black',linewidths=0.3);

# %% [markdown]
# ### Highest correlation are between Quantity and discount
# ### there is no any correlation between discount and profit

# %%
super_store['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
sns.countplot(x=super_store['Region']);

# %%
sns.countplot('Region',hue='Category',data=super_store);

# %%
plt.figure(figsize=[12,8])
sns.barplot(x=super_store['Sub-Category'],y=super_store['Profit'])
plt.xticks(rotation=90);

# %%
sns.pairplot(super_store,hue='Sub-Category');

# %%
plt.figure(figsize=[12,8])
super_store['Sub-Category'].value_counts().plot.pie(autopct="%1.1f%%");

# %%
super_store.hist(bins=50,figsize=(15,12));

# %%
super_store.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Region',
#        'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
store_group=pd.DataFrame(super_store.groupby(['Ship Mode','State','Segment','Region','Category','Sub-Category'])['Quantity','Sales','Discount','Profit'].sum().reset_index())
store_group
# Out:
#            Ship Mode      State      Segment   Region         Category  \
# 0        First Class    Alabama     Consumer    South        Furniture
# 1        First Class    Alabama    Corporate    South  Office Supplies
# 2        First Class    Alabama    Corporate    South  Office Supplies
# 3        First Class    Alabama    Corporate    South  Office Supplies
# 4        First Class    Alabama    Corporate    South  Office Supplies
# ...              ...        ...          ...      ...              ...
# 2978  Standard Class  Wisconsin  Home Office  Central  Office Supplies
# 2979  Standard Class  Wisconsin  Home Office  Central  Office Supplies
# 2980  Standard Class  Wisconsin  Home Office  Central       Technology
# 2981  Standard Class  Wisconsin  Home Office  Central       Technology
# 2982  Standard Class    Wyoming  Home Office     West        Furniture
#
#      Sub-Category  Quantity     Sales  Discount    Profit
# ...

# %%
pd.DataFrame(super_store.groupby('State').Profit.agg(['mean','sum','median','min','max','std','var']))
# Out:
#                             mean         sum     median        min        max  \
# State
# Alabama                94.865989   5786.8253   16.87500     0.0000  1459.2000
# Arizona               -15.303235  -3427.9246    2.53365  -814.4832   211.4955
# Arkansas               66.811452   4008.6871   18.34080     1.4190   843.1706
# California             38.171608  76381.3871   13.30560  -325.5720  1906.4850
# Colorado              -35.867351  -6527.8579    3.12480 -3399.9800   247.9960
# Connecticut            42.823071   3511.4918   12.18310   -15.5826   294.6710
# Delaware              103.930988   9977.3748   19.19700   -48.7839  5039.9856
# District of Columbia  105.958930   1059.5893   14.52720     4.4344   648.5624
# Florida                -8.875461  -3399.3017    2.93400 -1811.0784   327.5922
# Georgia                88.315453  16250.0433   22.24690     0.1134  3177.4750
# Idaho                  39.367767    826.7231   14.70000     1.1151   259.5297
# ...

# %%
print(super_store['Sales'].describe())
sns.boxplot(super_store['Sales']);
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Sales, dtype: float64

# %%
print(super_store['Discount'].describe())
sns.boxplot(super_store['Discount']);
# Out:
# count    9994.000000
# mean        0.156203
# std         0.206452
# min         0.000000
# 25%         0.000000
# 50%         0.200000
# 75%         0.200000
# max         0.800000
# Name: Discount, dtype: float64

# %%
 print(super_store['Profit'].describe())
sns.boxplot(super_store['Profit']);
# Out:
# count    9994.000000
# mean       28.656896
# std       234.260108
# min     -6599.978000
# 25%         1.728750
# 50%         8.666500
# 75%        29.364000
# max      8399.976000
# Name: Profit, dtype: float64

# %%
print(super_store['Sales'].describe())
sns.distplot(super_store['Sales'],bins=100,color='r');
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Sales, dtype: float64

# %%
sns.scatterplot(super_store['Sales'],super_store['Profit'])
plt.title('Sales vs Profit\n',fontsize=20,color='g')
plt.xlabel('Sales',fontsize=15,color='r')
plt.ylabel('Profit',fontsize=15,color='r');

# %%
sns.scatterplot(super_store['Sales'],super_store['Discount'])
plt.title('Sales vs Discount\n',fontsize=20,color='b')
plt.xlabel('Sales',fontsize=15,color='r')
plt.ylabel('Discount',fontsize=15,color='r');

# %%
Q1 = super_store.quantile(q = 0.25, axis = 0, numeric_only = True, interpolation = 'linear')

Q3 = super_store.quantile(q = 0.75, axis = 0, numeric_only = True, interpolation = 'linear')

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# Sales       192.66000
# Quantity      3.00000
# Discount      0.20000
# Profit       27.63525
# dtype: float64
